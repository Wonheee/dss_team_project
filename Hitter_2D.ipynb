# %%
df_hitter_perf = pd.read_csv('./data/hitter_perf.csv', index_col=0)
df_hitter_etc = pd.read_csv('./data/hitter_etc.csv', index_col=0)

# %%
df_hitter_perf.columns, df_hitter_etc.columns
# Out:
# (Index([u'이름', u'연도', u'연봉(=Y)', u'총액(억)', u'계약년수(년)', u'년도', u'AVG_A',
#         u'OBP_A', u'SLG_A', u'WAR_A', u'HR%_A', u'BB%_A', u'K%_A', u'BIPA_A',
#         u'Spd_A', u'PSN_A', u'wOBA_A', u'wRC_A', u'wRAA_A', u'AVG_B', u'OBP_B',
#         u'SLG_B', u'WAR_B', u'HR%_B', u'BB%_B', u'K%_B', u'BIPA_B', u'Spd_B',
#         u'PSN_B', u'wOBA_B', u'wRC_B', u'wRAA_B'],
#        dtype='object'),
#  Index([u'Name', u'Year', u'Spectators', u'TitleSponsors', u'Broadcasting',
#         u'GDP', u'Clubs', u'FA_Pitcher', u'FA_Hitter', u'BirthYear', u'Age',
#         u'Captain', u'NationalMember', u'Marriage', u'Surgery', u'Salary',
#         u'Total', u'Period', u'Transfer', u'GoldenGlove', u'Rookie', u'AllStar',
#         u'Interest', u'Inflation', u'Hometown', u'RewardPlayer',
#         u'PreviousTeam', u'NewTeam', u'Position'],
#        dtype='object'))

# %%
dfX_hitter_perf = df_hitter_perf[['AVG_A', 'OBP_A', 'SLG_A', 'WAR_A', 'HR%_A', 'BB%_A', 'K%_A', 'BIPA_A', 'Spd_A', 'PSN_A', 'wOBA_A', 'wRC_A', 'wRAA_A', 'AVG_B', 'OBP_B', 'SLG_B', 'WAR_B', 'HR%_B', 'BB%_B', 'K%_B', 'BIPA_B', 'Spd_B', 'PSN_B', 'wOBA_B', 'wRC_B', 'wRAA_B']]
dfX_hitter_perf.columns=['AVG_A', 'OBP_A', 'SLG_A', 'WAR_A', 'HR_A', 'BB_A', 'K_A', 'BIPA_A', 'Spd_A', 'PSN_A', 'wOBA_A', 'wRC_A', 'wRAA_A', 'AVG_B', 'OBP_B', 'SLG_B', 'WAR_B', 'HR_B', 'BB_B', 'K_B', 'BIPA_B', 'Spd_B', 'PSN_B', 'wOBA_B', 'wRC_B', 'wRAA_B']
dfX_hitter_etc = df_hitter_etc[['Spectators','Broadcasting', 'GDP','Clubs','FA_Pitcher','FA_Hitter', 'Age', 'Captain', 'NationalMember', 'Marriage', 'Surgery', 'Transfer', 'GoldenGlove', 'Rookie', 'AllStar']]
dfy_hitter = df_hitter_perf[['계약년수(년)']]
dfy_hitter.columns = ['Year']

# %%
dfy_hitter.columns
# Out:
# Index([u'Year'], dtype='object')

# %%
idx = dfy_hitter == '-'
df_hitter = pd.concat([dfX_hitter_perf, dfX_hitter_etc, dfy_hitter], axis=1)
df_hitter.ix[idx]['Year'] = 0
df_hitter = sm.add_constant(df_hitter).astype(float)
# Out:
# ValueErrorTraceback (most recent call last)
# <ipython-input-26-3ef78d1a8ef9> in <module>()
#       1 idx = dfy_hitter == '-'
#       2 df_hitter = pd.concat([dfX_hitter_perf, dfX_hitter_etc, dfy_hitter], axis=1)
# ----> 3 df_hitter.ix[idx]['Year'] = 0
#       4 df_hitter = sm.add_constant(df_hitter).astype(float)
#
# /home/dockeruser/anaconda2/lib/python2.7/site-packages/pandas/core/indexing.pyc in __getitem__(self, key)
#      85         else:
#      86             key = com._apply_if_callable(key, self.obj)
# ---> 87             return self._getitem_axis(key, axis=0)
#      88
#      89     def _get_label(self, label, axis=0):
#
# /home/dockeruser/anaconda2/lib/python2.7/site-packages/pandas/core/indexing.pyc in _getitem_axis(self, key, axis)
#    1010
#    1011             if hasattr(key, 'ndim') and key.ndim > 1:
# -> 1012                 raise ValueError('Cannot index with multidimensional key')
#    1013
#    1014             return self._getitem_iterable(key, axis=axis)
#
# ValueError: Cannot index with multidimensional key

# %%
model = sm.OLS(df_hitter.ix[:,-2:],df_hitter.ix[:,:-2])
result = model.fit()
print(result.summary())
# Out:
# ValueErrorTraceback (most recent call last)
# <ipython-input-24-7c0af5f14c5a> in <module>()
#       1 model = sm.OLS(df_hitter.ix[:,-2:],df_hitter.ix[:,:-2])
#       2 result = model.fit()
# ----> 3 print(result.summary())
#
# /home/dockeruser/anaconda2/lib/python2.7/site-packages/statsmodels/regression/linear_model.pyc in summary(self, yname, xname, title, alpha)
#    2203             top_left.append(('Covariance Type:', [self.cov_type]))
#    2204
# -> 2205         top_right = [('R-squared:', ["%#8.3f" % self.rsquared]),
#    2206                      ('Adj. R-squared:', ["%#8.3f" % self.rsquared_adj]),
#    2207                      ('F-statistic:', ["%#8.4g" % self.fvalue] ),
#
# /home/dockeruser/anaconda2/lib/python2.7/site-packages/statsmodels/tools/decorators.pyc in __get__(self, obj, type)
#      95         if _cachedval is None:
#      96             # Call the "fget" function
# ---> 97             _cachedval = self.fget(obj)
#      98             # Set the attribute in obj
#      99             # print("Setting %s in cache to %s" % (name, _cachedval))
#
# /home/dockeruser/anaconda2/lib/python2.7/site-packages/statsmodels/regression/linear_model.pyc in rsquared(self)
#    1384     def rsquared(self):
#    1385         if self.k_constant:
# -> 1386             return 1 - self.ssr/self.centered_tss
#    1387         else:
#    1388             return 1 - self.ssr/self.uncentered_tss
#
# /home/dockeruser/anaconda2/lib/python2.7/site-packages/statsmodels/tools/decorators.pyc in __get__(self, obj, type)
#      95         if _cachedval is None:
#      96             # Call the "fget" function
# ---> 97             _cachedval = self.fget(obj)
#      98             # Set the attribute in obj
#      99             # print("Setting %s in cache to %s" % (name, _cachedval))
#
# /home/dockeruser/anaconda2/lib/python2.7/site-packages/statsmodels/regression/linear_model.pyc in ssr(self)
#    1356     def ssr(self):
#    1357         wresid = self.wresid
# -> 1358         return np.dot(wresid, wresid)
#    1359
#    1360     @cache_readonly
#
# ValueError: shapes (125,2) and (125,2) not aligned: 2 (dim 1) != 125 (dim 0)
